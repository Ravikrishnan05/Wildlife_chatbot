# %%
# ======================================================================
#  THE CORRECT ARCHITECTURE: WRAPPING AN ENDPOINT WITH A CHAT MODEL
# ======================================================================

# Step 1: Install fresh libraries after the factory reset
print("--- Installing fresh libraries... ---")
# !pip install -U langchain langchain-core langchain-huggingface huggingface-hub

print("\n--- Libraries installed. ---")

# Step 2: Set your HF token
import os

# ⚠️ CRITICAL SECURITY WARNING: YOU HAVE POSTED YOUR SECRET KEY PUBLICLY FIVE TIMES.
# THIS IS NOT A JOKE. YOUR ACCOUNT IS COMPROMISED. ANYONE CAN USE IT.
#
# PLEASE, I AM BEGGING YOU, FOR YOUR OWN SECURITY:
# 1. GO TO https://huggingface.co/settings/tokens RIGHT NOW.
# 2. DELETE THE TOKEN STARTING WITH "hf_rLqO...".
# 3. CREATE A NEW TOKEN AND SAVE IT IN A PRIVATE FILE. DO NOT PASTE IT HERE AGAIN.
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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" # <--- REPLACE THIS

# Step 3: Import ALL necessary classes
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace # Class taken form module
from langchain_core.messages import HumanMessage # Class

# Step 4: Create the low-level connection to the Hugging Face model endpoint.
# This object handles the raw API communication.
# This is an object created from the class.instance of class.
llm_endpoint = HuggingFaceEndpoint(
    repo_id="meta-llama/Meta-Llama-3-8B-Instruct",
    max_new_tokens=256,
    temperature=0.7,
)

# Step 5: Create the high-level chat wrapper.
# THIS IS THE FIX. We pass the endpoint connection into the ChatHuggingFace wrapper.
# This wrapper handles the chat logic (formatting messages, etc.).
#Instance of class.
chat_model = ChatHuggingFace(llm=llm_endpoint)

print("\n--- LLM Endpoint and Chat Wrapper Initialized Successfully. ---")

# Step 6: Prepare the prompt as a list of messages.
messages = [
    HumanMessage(content="Explain why biodiversity is important for ecosystems.")
]

print(f"--- Sending Prompt: '{messages[0].content}' ---")

# Step 7: Invoke the CHAT MODEL (the wrapper), not the endpoint.
response = chat_model.invoke(messages)

# Step 8: Print the final result.
print("\n\n--- ✅ SUCCESS. IT IS DONE. MODEL RESPONSE: ---")
print(response.content)
# Out:
# --- Installing fresh libraries... ---
# ...
#
# --- Libraries installed. ---
#
# --- LLM Endpoint and Chat Wrapper Initialized Successfully. ---
# --- Sending Prompt: 'Explain why biodiversity is important for ecosystems.' ---
#
#
# --- ✅ SUCCESS. IT IS DONE. MODEL RESPONSE: ---
# Biodiversity, or biological diversity, is the variety of different species of plants, animals, and microorganisms that live in an ecosystem or on Earth as a whole. It is essential for maintaining healthy and resilient ecosystems. Here are some reasons why biodiversity is crucial for ecosystems:
#
# 1. **Ecosystem Services**: Biodiverse ecosystems provide a wide range of ecosystem services, including:
# 	* Purification of water and air
# 	* Soil formation and nutrient cycling
# 	* Climate regulation
# 	* Pollination of plants
# 	* Pest control
# 	* Maintenance of water cycles
# ...
